# %%
# %%writefile new.py
import streamlit as st
from PIL import Image
import time
import pandas as pd
import plotly.express as px 
import numpy as np
import requests
from io import BytesIO
import locale
import concurrent.futures
import re
import requests
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import random




st.set_page_config(layout="wide")


def load_data():
    exp = pd.read_csv("C:\\Users\\user\\Downloads\\mid project\\ali express datasets\\Ali_express_dataset.csv")
    return exp

exp = load_data()

def delay():
    global select_page

    if 'run_main1' not in st.session_state and select_page is None:
        col1 , col2, col3, col4 = st.columns(4)
        
        with col2:
            
            img_path = "C:\\Users\\user\\Downloads\\mid project\\pic\\301604651_384010200569549_7017712053271319483_n.png"
            img = Image.open(img_path)
            st.image(img, caption="Powered By Mohammad Ghadieh", width=600)
            time.sleep(1)
            st.session_state['run_main1'] = True
            select_page = 'Home 🏠'
            st.experimental_rerun()  # Rerun the app to go to the selected page

def Home():  
    

    # Set the background image for the dashboard
    page_bg_img = """
    <style>
    [data-testid="stAppViewContainer"] {
    background-image: url("https://img.freepik.com/premium-photo/global-network-5g-high-speed-internet-communication_24070-1256.jpg?w=826");
    background-size: cover;
    }
    
    [data-testid="stHeader"] {
    background: rgba(0,0,0,0);
    }
    
    [data-testid="stToolbar"] {
    right: 2rem;
    }
    </style>
    """
    
    st.markdown(page_bg_img, unsafe_allow_html=True)   
    
    st.markdown('<style>h1{color: white;}</style>', unsafe_allow_html=True)
    st.title('Visualization Charts')
 
    store_discounts = exp.groupby('storeName')['discount'].mean().sort_values(ascending=False).head(10)
    
    f1 = px.bar(
        x=store_discounts.index,
        y=store_discounts.values,
        color=store_discounts.index,
        labels={'x': 'Store', 'y': 'Average Discount'},
        title='Top 10 Stores with the Highest Discounts'
    )
    
    f1.update_layout(xaxis={'tickangle': 45, 'tickfont': {'size': 10}})
    
    st.plotly_chart(f1)
    
    ##
    store_rating= exp.groupby('storeName')['rating'].mean().nlargest(10)
    
    f2 = px.bar(
        x=store_rating.index,
        y=store_rating.values,
        color=store_rating.index,
        labels={'x': 'Store', 'y': 'Average rating'},
        title='Top 10 Stores with the Highest rating'
    )
    
    f2.update_layout(xaxis={'tickangle': 45, 'tickfont': {'size': 10}})
    
    st.plotly_chart(f2)
    
    ##
    
    type_discount = exp.groupby('product_type')['discount'].mean().sort_values(ascending=False).head(10)
    
    f3 = px.bar(
        x=type_discount.index,
        y=type_discount.values,
        color=type_discount.values,
        labels={'x': 'Products Type', 'y': 'Average Discount'},
        title='Average Discount by Products Type'
    )
    
    f3.update_layout(xaxis={'tickangle': 45, 'tickfont': {'size': 9}})
    st.plotly_chart(f3)
    
    ##
    category_avg_price = exp.groupby('product_type')['price'].mean().sort_values(ascending=False).head(10)
    
    f4 = px.bar(
        x=category_avg_price.index,
        y=category_avg_price.values,
        color=category_avg_price.values,
        labels={'x': 'Products Type', 'y': 'Average price'},
        title='Average price by Products Type'
    )
    
    f4.update_layout(xaxis={'tickangle': 45, 'tickfont': {'size': 9}})
    st.plotly_chart(f4)
    ##
    
    category_avg_sold = exp.groupby('product_type')['sold'].mean().sort_values(ascending=False).head(10)
    
    f5 = px.bar(
        x=category_avg_sold.index,
        y=category_avg_sold.values,
        color=category_avg_sold.values,
        labels={'x': 'Products Type', 'y': 'Average sold'},
        title='Average sold by Products Type'
    )
    
    f5.update_layout(xaxis={'tickangle': 45, 'tickfont': {'size': 9}})
    
    st.plotly_chart(f5)
    ##
    
    category_avg_shippingCost = exp.groupby('product_type')['shippingCost'].mean().sort_values(ascending=False).head(10)
    
    f6 = px.bar(
        x=category_avg_shippingCost.index,
        y=category_avg_shippingCost.values,
        color=category_avg_shippingCost.values,
        labels={'x': 'Products Type', 'y': 'Average sold'},
        title='Average shippingCost by Products Type'
    )
    
    f6.update_layout(xaxis={'tickangle': 45, 'tickfont': {'size': 9}})
    
    st.plotly_chart(f6)
    
    ##
    
    store_avg_sold = exp.groupby('storeName')['sold'].mean().sort_values(ascending=False).head(10)
    
    f7 = px.bar(
        x=store_avg_sold.index,
        y=store_avg_sold.values,
        color=store_avg_sold.values,
        labels={'x': 'Store', 'y': 'Average sold'},
        title='Average sold by Store'
    )
    
    f7.update_layout(xaxis={'tickangle': 45, 'tickfont': {'size': 9}})
    st.plotly_chart(f7)
    ##
    monthly_sales = exp.groupby('month_name').size().reset_index(name='Number of Sales')
    
    f8 = px.line(
        monthly_sales, 
        x='month_name', 
        y='Number of Sales',
        markers=True,  
        title='Monthly Sales'
    )
    
    f8.update_layout(
        xaxis={'tickangle': 45, 'tickfont': {'size': 9}},
        yaxis={'title': 'Number of Sales'}
    )
    
    st.plotly_chart(f8)

        



          
            
def Shop():
    p1 , p2 , p3 , p4 , p5 , p6 , p7 , p8 , p9 , p10 ,p11 , p12 ,p13 = st.tabs(['Home & Lifestyle', 
       'Electronics & Gadgets', 'Outfit & Accessories',
       'Lighting & Fixtures','Beauty & Personal Care', 'Sports & Outdoor','Books & Entertainment', 
       'Office & School Supplies', 'Toys & Games', 'Baby & Child Care',
       'Security & Protection', 'Automotive & Vehicles', 'Others'])
    


    with p1:
        

        filter_data = exp['imageUrl'][exp['product_type'] == 'Home & Lifestyle'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)

                

  
    
    
    
    
            
    with p2:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Electronics & Gadgets'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)        
    
    with p3:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Outfit & Accessories'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
            
    with p4:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Lighting & Fixtures'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
            
        
    with p5:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Beauty & Personal Care'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
            
    with p6:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Sports & Outdoor'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
            
    
    with p7:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Books & Entertainment'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
                
                
    with p8:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Office & School Supplies'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
    
    with p9:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Toys & Games'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price

                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price

                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)

                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
    
    with p10:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Baby & Child Care'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
                
                
    with p11:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Security & Protection'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
                
                
    with p12:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Automotive & Vehicles'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)      
        
    with p13:
        filter_data = exp['imageUrl'][exp['product_type'] == 'Others'].values
        random_data = random.sample(filter_data.tolist(), k=min(10, len(filter_data)))
        for link in random_data:
            img_url = "https:" + link
            response = requests.get(img_url)
            img = Image.open(BytesIO(response.content))
            title = exp['title'][exp['imageUrl'] == link].values[0]
            price = exp['price'][exp['imageUrl'] == link].values[0]
            rating = exp['rating'][exp['imageUrl'] == link].values[0]
            discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
            sold = exp['sold'][exp['imageUrl'] == link].values[0]
            
            cl1, cl2 = st.columns(2)
            with cl1:
                st.image(img, caption=title, width=400)
        
            with cl2:
                dollars, cents = "{:.2f}".format(discounted).split('.')
                formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                
                # Display the old price with a strikethrough
                old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                
                # Display the number of items sold
                st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                
                # Display the star rating
                stars = '⭐️' * int(rating)
                empty_stars = '☆' * (5 - int(rating))
                st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
                
                

def Search():
    page_bg_img = """
    <style>
    [data-testid="stAppViewContainer"] {
    background-image: url("https://img.freepik.com/premium-photo/concept-logistics-delivery-goods-shopping-cart-with-boxes-goods-background-world-map-with-transport_102583-6806.jpg?w=826");
    background-size: cover;
    }
    
    [data-testid="stHeader"] {
    background: rgba(0,0,0,0);
    }
    
    [data-testid="stToolbar"] {
    right: 2rem;
    }
   
    </style>
    """
    
    st.markdown(page_bg_img, unsafe_allow_html=True) 
    tb1,tb2 = st.tabs(['One Item','Recommendations'])
    
    with tb1:
        st.markdown(
            """
            <style>
            .custom-subheader {
                color: white;
            }
            </style>
            """,
            unsafe_allow_html=True
        )
        
        st.write('<h2 class="custom-subheader">Find The Item That You Are Searching For 💡</h2>', unsafe_allow_html=True)
        query = st.text_input('Search')
        # If the user has entered a query, perform the search and display similar titles
        
        
        if query:
            exp_filtered = exp[exp.title.str.contains('|'.join(query.split()), case=False, regex=True)]
            similar_titles = exp_filtered.title[exp_filtered.title.apply(
                lambda x: all(keyword.lower() in x.lower() for keyword in query.split()))]
            
            try:
                if not similar_titles.empty:
                    for idx, title in enumerate(similar_titles[:3]):
                        if st.button(title, key=f"button_{idx}"):
                            query = title  # Set the query to the title of the button clicked
                            img_path = exp['imageUrl'][exp['title'].str.contains(query)].values[:1]
                            if img_path:
                                
                                for link in img_path:
                                    img_url = "https:" + link
                                    response = requests.get(img_url)
                                    img = Image.open(BytesIO(response.content))
                                    title = exp['title'][exp['imageUrl'] == link].values[0]
                                    price = exp['price'][exp['imageUrl'] == link].values[0]
                                    rating = exp['rating'][exp['imageUrl'] == link].values[0]
                                    discounted = (exp['price'][exp['imageUrl'] == link] * (1 - exp['discount'][exp['imageUrl'] == link] / 100)).values[0]
                                    sold = exp['sold'][exp['imageUrl'] == link].values[0]
                                    
                                    
                                cl1, cl2 = st.columns(2)
                                
                                with cl1:
                                    st.image(img, caption=title, width=400)
                            
                                with cl2:
                                    dollars, cents = "{:.2f}".format(discounted).split('.')
                                    formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                                    colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                                    st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                                    
                                    # Display the old price with a strikethrough
                                    old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                                    st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                                    
                                    # Display the number of items sold
                                    st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                                    
                                    # Display the star rating
                                    stars = '⭐️' * int(rating)
                                    empty_stars = '☆' * (5 - int(rating))
                                    st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
            except:
                st.write("No matching Items found.")
                                    
############################################################################
    with tb2:
        

        st.markdown('<h2 style="color: white;">Get Recommendations For What In Your Mind 💡</h2>', unsafe_allow_html=True)
        
        query = st.text_input('Search', key='query')
        
        # If the user has entered a query, perform the search and display similar titles
        if query:
            exp_filtered = exp[exp.title.str.contains('|'.join(query.split()), case=False, regex=True)]
            similar_titles = exp_filtered.title[exp_filtered.title.apply(
                lambda x: all(keyword.lower() in x.lower() for keyword in query.split()))]
            if not similar_titles.empty:
                for idx, title in enumerate(similar_titles[:3]):
                    if st.button(title, key=f"button_{idx}"):
                        query = title  # Set the query to the title of the button clicked
                        img_path = exp['imageUrl'][exp['title'].str.contains(query)].values[:1]
                        if img_path:
                            linkr = img_path[0]
        
        
        
                            nid = exp[exp['imageUrl']==  linkr].index.values[0]
                            
                            # Filtered data
                            filtered_data = exp
                            
                            # Define the columns for one-hot encoding and TF-IDF transformation
                            categorical_cols = ['title']
                            categorical_cols2 = ['category_name']
                            categorical_cols3 = ['product_type']
                            numerical_col = ['customer_saving']
                            
                            
                            
                            
                            # Create the column transformer
                            preprocessor = ColumnTransformer([
                                ('onehot', OneHotEncoder(), categorical_cols),
                                ('onehot2', OneHotEncoder(), categorical_cols2),
                                ('onehot3', OneHotEncoder(), categorical_cols3),
                                ('scaling', StandardScaler(), numerical_col)
                            ])
                            
                            filtered_data['customer_saving'] = filtered_data['customer_saving'].astype(str)
                            # Transform the input features
                            X = preprocessor.fit_transform(filtered_data)
                            
                            # Create the k-nearest neighbors classifier
                            knn = KNeighborsClassifier(n_neighbors=5, metric='cosine')
                            
                            # Fit the classifier to the transformed data
                            knn.fit(X, filtered_data['id'])
                            
                            # Define the function to get item recommendations
                            def get_item_recommendations(item_id, top_n=5):
                                # Reshape the item features
                                item_features = preprocessor.transform(filtered_data.loc[[item_id]])
                            
                                # Find the nearest neighbors
                                distances, neighbor_indices = knn.kneighbors(item_features)
                            
                                # Get the recommended item IDs
                                recommendations = filtered_data.iloc[neighbor_indices[0]].index.tolist()
                            
                                return recommendations[:top_n]
                            
                            item_id = nid  # ID of the item for which you want recommendations
                            top_recommendations = get_item_recommendations(item_id, top_n=5)
                            for top in top_recommendations:
                                linkrec = exp['imageUrl'][exp.index == top].values[0]
                                img_url1 = "https:" + linkrec
                                response = requests.get(img_url1)
                                img = Image.open(BytesIO(response.content))
                                title = exp['title'][exp['imageUrl'] == linkrec].values[0]
                                price = exp['price'][exp['imageUrl'] == linkrec].values[0]
                                rating = exp['rating'][exp['imageUrl'] == linkrec].values[0]
                                discounted = (exp['price'][exp['imageUrl'] == linkrec] * (1 - exp['discount'][
                                    exp['imageUrl'] == linkrec] / 100)).values[0]
                                sold = exp['sold'][exp['imageUrl'] == linkrec].values[0]
                                
                                cl1,cl2 = st.columns(2)
                                with cl1:
                                    st.image(img, caption=title, width=400)
                    
                                with cl2:
                                    dollars, cents = "{:.2f}".format(discounted).split('.')
                                    formatted_price = f'<span style="font-size: 32px; font-weight: bold;">{dollars}</span>.<span style="font-size: 24px; font-weight: bold;">{cents}</span>'
                                    colored_price = '<span style="color: #FF0000;">' + formatted_price + '</span>'
                                    st.markdown("US $" + colored_price, unsafe_allow_html=True)  # Display formatted and colored price
                                    
                                    # Display the old price with a strikethrough
                                    old_price_strikethrough = '<span style="text-decoration: line-through; font-size: 20px; font-weight: bold;">${:.2f}</span>'.format(price)
                                    st.markdown(old_price_strikethrough, unsafe_allow_html=True)  # Display formatted and colored price with old price
                                    
                                    # Display the number of items sold
                                    st.markdown("<span style='font-size: 20px;'>{} Sold</span>".format(sold), unsafe_allow_html=True)
                                    
                                    # Display the star rating
                                    stars = '⭐️' * int(rating)
                                    empty_stars = '☆' * (5 - int(rating))
                                    st.markdown("<span style='font-size: 24px; font-weight: bold;'>{}{}</span>".format(stars, empty_stars), unsafe_allow_html=True)
                        else:
                            st.write("No matching recommendations found.")

pages = {
    'Home 🏠': Home,
    'Shop 🛍️': Shop,
    'Search 🔍': Search
}

select_page = None

if 'run_main' not in st.session_state:
    delay()
    st.session_state['run_main'] = True

if select_page is None:
    select_page = st.sidebar.selectbox('Select Page', list(pages.keys()), index=0)

if select_page:
    st.session_state['run_main'] = True  
    with st.sidebar:
        st.markdown('## Menu')
        st.markdown(f'Current Page: {select_page}')
    pages[select_page]()
    st.session_state['select_page'] = select_page  # Remember the selected page
# Out:
# Overwriting new.py

# %%
! streamlit run new.py
